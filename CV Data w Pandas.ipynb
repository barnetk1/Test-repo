# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
asv = pd.read_excel("ASV data set 1.xlsx", sheet_name="Cd scan rates", index=False)

# %%
asv
# Out:
#             Column1       Column2  Unnamed: 2       Column1.1     Column2.1  \
# 0    Potential (mV)   Current (A)         NaN  Potential (mV)   Current (A)
# 1           #10mV/s           NaN         NaN         #20mV/s           NaN
# 2            -799.0     1.462e-07         NaN          -799.0     1.489e-07
# 3            -798.0     1.469e-07         NaN          -798.0     1.474e-07
# 4            -797.0     1.442e-07         NaN          -797.0      1.47e-07
# 5            -796.0     1.433e-07         NaN          -796.0     1.455e-07
# 6            -795.0     1.419e-07         NaN          -795.0     1.446e-07
# 7            -794.0     1.408e-07         NaN          -794.0     1.434e-07
# 8            -793.0      1.39e-07         NaN          -793.0     1.418e-07
# 9            -792.0     1.379e-07         NaN          -792.0     1.406e-07
# 10           -791.0     1.375e-07         NaN          -791.0     1.389e-07
# ...

# %%
asv.iloc[2:452, 0:2]
# Out:
#     Column1    Column2
# 2    -799.0  1.462e-07
# 3    -798.0  1.469e-07
# 4    -797.0  1.442e-07
# 5    -796.0  1.433e-07
# 6    -795.0  1.419e-07
# 7    -794.0  1.408e-07
# 8    -793.0   1.39e-07
# 9    -792.0  1.379e-07
# 10   -791.0  1.375e-07
# 11   -790.0  1.358e-07
# 12   -789.0  1.353e-07
# 13   -788.0  1.345e-07
# 14   -787.0  1.338e-07
# 15   -786.0  1.335e-07
# 16   -785.0  1.324e-07
# 17   -784.0   1.32e-07
# 18   -783.0  1.317e-07
# 19   -782.0  1.307e-07
# 20   -781.0  1.304e-07
# 21   -780.0  1.297e-07
# 22   -779.0   1.29e-07
# 23   -778.0  1.289e-07
# 24   -777.0  1.281e-07
# 25   -776.0  1.276e-07
# 26   -775.0  1.275e-07
# 27   -774.0  1.264e-07
# 28   -773.0  1.263e-07
# 29   -772.0  1.256e-07
# 30   -771.0  1.244e-07
# 31   -770.0  1.238e-07
# ..      ...        ...
# 422  -379.0 -4.926e-09
# 423  -378.0 -3.575e-09
# 424  -377.0 -3.444e-09
# 425  -376.0 -2.965e-09
# 426  -375.0   -1.7e-09
# 427  -374.0 -1.395e-09
# 428  -373.0 -1.046e-09
# 429  -372.0 -7.847e-10
# ...

# %%
asv2 = asv.iloc[2:452, 0:2]
asv2.plot(legend=False)

# %%
Potential = asv.iloc[2:452, 0]
Current = asv.iloc[2:452, 1]
fig1 = plt.plot(Potential, Current)
fig1 = plt.xlabel("Potential (mV)")
fig1 = plt.ylabel("Current (A)")
x=Potential
y=Current
ymax = max(y)
print(ymax)
#change this because I actually want minimum value
# Out:
# 1.469e-07

# %%
#Next steps: figuring out how to get x-axis labels again lol, how to get x max as needed
#plt.xticks((0,3,4,7,10))
#arange = set potential values I want
#Can manually set location of ticks
# Out:
# 2      -799.0
# 3      -798.0
# 4      -797.0
# 5      -796.0
# 6      -795.0
# 7      -794.0
# 8      -793.0
# 9      -792.0
# 10     -791.0
# 11     -790.0
# 12     -789.0
# 13     -788.0
# 14     -787.0
# 15     -786.0
# 16     -785.0
# 17     -784.0
# 18     -783.0
# 19     -782.0
# 20     -781.0
# 21     -780.0
# 22     -779.0
# 23     -778.0
# 24     -777.0
# 25     -776.0
# 26     -775.0
# 27     -774.0
# 28     -773.0
# 29     -772.0
# 30     -771.0
# 31     -770.0
#         ...
# 422    -379.0
# 423    -378.0
# 424    -377.0
# 425    -376.0
# 426    -375.0
# 427    -374.0
# 428    -373.0
# 429    -372.0
# 430    -371.0
# 431    -370.0
# 432    -369.0
# 433    -368.0
# 434    -367.0
# 435    -366.0
# 436    -365.0
# 437    -364.0
# 438    -363.0
# 439    -362.0
# 440    -361.0
# 441    -360.0
# 442    -359.0
# 443    -358.0
# 444    -357.0
# 445    -356.0
# 446    -355.0
# 447    -354.0
# 448    -353.0
# 449    -352.0
# 450    -351.0
# 451    -350.0
# ...
